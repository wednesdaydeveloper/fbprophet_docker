# %% [markdown]
# # Prophet Quick Start
# https://facebook.github.io/prophet/docs/quick_start.html

# %%
import pandas as pd
from fbprophet import Prophet

df = pd.read_csv('./example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet(daily_seasonality=True)
m.fit(df)

future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.205780    7.456390    8.865965
# 3266 2017-01-16  8.530823    7.831394    9.209940
# 3267 2017-01-17  8.318218    7.618142    9.045318
# 3268 2017-01-18  8.150826    7.391006    8.837384
# 3269 2017-01-19  8.162728    7.448745    8.840318

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)
